# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)

# %%
from google.colab.patches import cv2_imshow
import cv2
rasm=cv2.imread('rasm.png')
rasm1=cv2.imread('rasm1.jpg')
rasm2=cv2.imread('rasm2.png')
rasm3=cv2.imread('rasm3.jpg')
rasm4=cv2.imread('rasm4.jpg')
cv2_imshow(rasm)
cv2_imshow(rasm1)
cv2_imshow(rasm2)
cv2_imshow(rasm3)
cv2_imshow(rasm4)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>
# <PIL.Image.Image image mode=RGB size=383x422>
# <PIL.Image.Image image mode=RGB size=383x422>
# <PIL.Image.Image image mode=RGB size=386x412>
# <PIL.Image.Image image mode=RGB size=391x422>

# %%
oqqora=cv2.cvtColor(rasm,cv2.COLOR_BGR2GRAY)
oqqora1=cv2.cvtColor(rasm1,cv2.COLOR_BGR2GRAY)
oqqora2=cv2.cvtColor(rasm2,cv2.COLOR_BGR2GRAY)
oqqora3=cv2.cvtColor(rasm3,cv2.COLOR_BGR2GRAY)
oqqora4=cv2.cvtColor(rasm4,cv2.COLOR_BGR2GRAY)
cv2_imshow(oqqora)
cv2_imshow(oqqora1)
cv2_imshow(oqqora2)
cv2_imshow(oqqora3)
cv2_imshow(oqqora4)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080>
# <PIL.Image.Image image mode=L size=383x422>
# <PIL.Image.Image image mode=L size=383x422>
# <PIL.Image.Image image mode=L size=386x412>
# <PIL.Image.Image image mode=L size=391x422>
